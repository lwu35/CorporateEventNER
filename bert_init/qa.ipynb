# %%
# !pip install simpletransformers

# %%
import logging

from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs


logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)


train_data = [
    {
        "context": "2021 Astronics Corporation Annual Meeting of Shareholders",
        "qas": [
            {
                "id": "00001",
                "is_impossible": False,
                "question": "What is the event type?",
                "answers": [
                    {
                        "text": "Annual Meeting of Shareholders",
                        "answer_start": 28,
                    }
                ],
            }
        ],
    },
    {
        "context": "Itron 2021 Q1 earnings release 05/03/2021 10:00 AM EDT"
              ,
        "qas": [
            {
                "id": "00002",
                "is_impossible": False,
                "question": "What is the event type?",
                "answers": [
                    {
                        "text": "earnings release",
                        "answer_start": 14,
                    }
                ],
            },
        ],
    },
        {
        "context": "efi + sirus capital group acquisition",
        "qas": [
            {
                "id": "00003",
                "is_impossible": False,
                "question": "What is the event type?",
                "answers": [
                    {
                        "text": "acquisition",
                        "answer_start": 26,
                    }
                ],
            }
        ],
    },
            {
        "context": "MAY 19, 2021 5:00PM EDTSutro Biopharma Announces Additional Data for Dose-Escalation Phase 1 Study of STRO-002 to be Presented at ASCO 2021",
        "qas": [
            {
                "id": "00004",
                "is_impossible": False,
                "question": "What is the event type?",
                "answers": [
                    {
                        "text": "ASCO 2021",
                        "answer_start": 132,
                    }
                ],
            }
        ],
    },
                {
        "context": "BrightView 2021 Q2 earnings call 05/06/2021 10:00 AM EST",
        "qas": [
            {
                "id": "00005",
                "is_impossible": False,
                "question": "What is the event type?",
                "answers": [
                    {
                        "text": "earnings call",
                        "answer_start": 20,
                    }
                ],
            }
        ],
    },
]

eval_data = [
    {
        "context": "BBVA USA Bancshares 2021 Q1 earnings release 04/30/2021 8:30 AM CDT",
        "qas": [
            {
                "id": "00001",
                "is_impossible": False,
                "question": "What is the event type?",
                "answers": [
                    {
                        "text": "earnings release",
                        "answer_start": 29,
                    },
                ],
            }
        ],
    },
    {
        "context": "Zynex 2020 Q4 + Y earnings release 02/25/2021 2:15 PM MST",
        "qas": [
            {
                "id": "00002",
                "is_impossible": False,
                "question": "What is the event type?",
                "answers": [
                    {
                        "text": "earnings release",
                        "answer_start": 19,
                    }
                ],
            },

        ],
    },
]

# Configure the model
model_args = QuestionAnsweringArgs()
model_args.train_batch_size = 16
model_args.evaluate_during_training = True
model_args.overwrite_output_dir = True
#model_args.fp16 = False

model = QuestionAnsweringModel(
    "roberta", "roberta-base", args=model_args
)

# Train the model
model.train_model(train_data, eval_data=eval_data)

# Evaluate the model
result, texts = model.eval_model(eval_data)

    # Make predictions with the model
to_predict = [
        {
            "context": "2021 Astronics Corporation Annual Meeting of Shareholders.",
            "qas": [
                {
                    "question": "What is the event type?",
                    "id": "0",
                }
            ],
        },
                {
            "context": "Fourth Quarter 2020 Earnings.",
            "qas": [
                {
                    "question": "What is the event type?",
                    "id": "1",
                }
            ],
        },
    ]

answers, probabilities = model.predict(to_predict)

print(answers)
# Out:
# 2021-07-07 13:34:45.986874: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForQuestionAnswering: ['lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight']
# - This IS expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
to_predict2 = [
        {
            "context": "7th Annual Communications Infrastructure Summit BOULDER, CO / VIRTUAL |AUG 09–12, 2021",
            "qas": [
                {
                    "question": "What is the event type?",
                    "id": "0",
                }
            ],
        },
                {
            "context": "Electronic Arts Q4 earnings call 05/11/2021 02:00 PM PT 866 324-3683 https://event.on24.com/wcc/r/3082295/44574BD8DABA0634EBAFFF035D3C8A3E",
            "qas": [
                {
                    "question": "What is the event type?",
                    "id": "1",
                }
            ],
        },
    ]

answers, probabilities = model.predict(to_predict2)

print(answers)
# Out:
# INFO:simpletransformers.question_answering.question_answering_model: Converting to features started.
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
to_predict3 = [
        {
            "context": "7th Annual Communications Infrastructure Summit BOULDER",
            "qas": [
                {
                    "question": "What is the event type?",
                    "id": "0",
                }
            ],
        },
                {
            "context": "Electronic Arts Q4 earnings call",
            "qas": [
                {
                    "question": "What is the event type?",
                    "id": "1",
                }
            ],
        },
    ]

answers, probabilities = model.predict(to_predict3)

print(answers)
# Out:
# INFO:simpletransformers.question_answering.question_answering_model: Converting to features started.
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['7th']}, {'id': '1', 'answer': ['4', 'Q4', 'Arts Q4']}]
